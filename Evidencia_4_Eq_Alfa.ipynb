# %% [markdown]
# <a href="https://colab.research.google.com/github/SOFIAARAUJO1946694/ANGELASOFIAARAUJOFRIAS/blob/main/Evidencia_4_Eq_Alfa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
examen= {"Diccionario":"Es una estructura de datos que permite almacenar cualquier tipo de información, desde cadenas de texto o caracteres hasta números enteros, con decimales, listas e incluso otros diccionarios.",
         "Funcion":"Son una parte del código encargadas de cumplir algún objetivo específico definido por nosotros o por el lenguaje",
         "Lista": "Son un tipo contenedor, compuesto, que se usan para almacenar conjuntos de elementos relacionados del mismo tipo o de tipos distintos",
         "Llave": "Se utiliza para accesar una información en un diccionario",
         "Variable":"Ubicaciones de memoria reservadas para almacenar valores",
         "Tupla":"Conjunto ordenado e inmutable de elementos del mismo o diferente tipo",
         "Index": "Ayuda a encontrar la posicion de un elemento o un item en una cadena de caracteres o una lista de items",
         "Variable de iteracion":"Cambia los valores de los parametros o las propiedades de Ruta de los nodos seleccionados en una ruta",
         "Matriz":"Coleccion ordenada de datos. Se emplean para almacenar multiples valores en una sola variable",
         "Sort":"Metodo integrado de Python que de forma predeterminada orden la lista en orden ascendennte",
         "Sorted":"Esta funcion devuelve una lista ordenada del objeto iterable especificado",
         "Sum":"Funcion nativa dedicada a calcular la suma de todos los elementos en una lista",
         "Break":"Proporciona la oportunidad de cerrar un bucle cuando se activa una condición externa",
         "Loop":"Es una serie de sentencias que se ejecutan durante un número de repeticiones especificado o hasta que se cumplen las condiciones especificadas",
         "While": "Es otra estructura de control de flujo, concretamente lo que hace es repetir un código mientras dure una determinada condición",
         "Pickle":"Realiza un seguimiento de los objetos que ya ha serializado, para que las referencias posteriores al mismo objeto no se serialicen nuevamente",
         "Pandas":"Es una librería de Python especializada en la manipulación y el análisis de datos. Ofrece estructuras de datos y operaciones para manipular tablas numéricas y series temporales, es como el Excel de Python",
         "Keys":"Devuelve un nuevo objeto Array Iterator que contiene las claves de índice con las que acceder a cada elemento en el array",
         "Range":"Proporciona una secuencia de enteros basada en los argumentos de la función",
         "Iterar":"Es la repetición de un segmento de código dentro de un programa de computadora"}

lista =[0,1,2,3]
letra = ["A","B","C","D"]

concepto = [ ]
for llave in examen.keys():
  concepto.append(llave)

# %%
concepto
# Out:
# ['Diccionario',
#  'Funcion',
#  'Lista',
#  'Llave',
#  'Variable',
#  'Tupla',
#  'Index',
#  'Variable de iteracion',
#  'Matriz',
#  'Sort',
#  'Sorted',
#  'Sum',
#  'Break',
#  'Loop',
#  'While',
#  'Pickle',
#  'Pandas',
#  'Keys',
#  'Range',
#  'Iterar']

# %%
import numpy as np

# %%
print("Bienvenido al examen de la 3ra y 4ta fase")
print(" ")
print("Contesta las preguntas escribiendo el concepto")
calif = 0
Np = 0
for inciso in examen.keys():
  correctas = concepto[:]
  correctas.remove(inciso)
  Np = Np+1
  print("")
  print(f"{Np}:{examen[inciso]}:")
  pos = int(np.random.choice(lista,1))

  respuestas= list(np.random.choice(correctas,3, replace=False))
  
  
  respuestas.insert(pos,inciso)
  for a, q in zip(letra, respuestas):
    print(f"{a}) {q}")

  guess=input("Concepto:")

  if guess == inciso:
    print("Muy bien :) correcto")
    calif = calif + (100/20)
  else:
    print("Muy mal :( incorrecto")
print(" ")
print(f"Tu calificación es de:{int(calif)}")

if (calif >= 0 and calif <= 50):
  print("Esfuerzate más")
else:
  if (calif >= 51 and calif <=60):
    print("No tan mal, puedes mejorar")
  else:
    if (calif >= 61 and calif <=70):
      print("Casi casi, te falta un poco más")
    else:
      if (calif >= 71 and calif <=80):
        print("Bien sigue así c:")
      else:
        if (calif >= 81 and calif <=90):
          print("Muy bien, no te rindas")
        else:
          if (calif >= 91 and calif <=100):
            print("Excelente 10/10")
# Out:
# Bienvenido al examen de la 3ra y 4ta fase
#
# Contesta las preguntas escribiendo el concepto
#
# 1:Es una estructura de datos que permite almacenar cualquier tipo de información, desde cadenas de texto o caracteres hasta números enteros, con decimales, listas e incluso otros diccionarios.:
# A) Pandas
# B) Pickle
# C) Sum
# D) Diccionario
# Concepto:Diccionario
# Muy bien :) correcto
#
# 2:Son una parte del código encargadas de cumplir algún objetivo específico definido por nosotros o por el lenguaje:
# A) Funcion
# B) Range
# C) Sort
# D) Matriz
# Concepto:Funcion
# Muy bien :) correcto
#
# 3:Son un tipo contenedor, compuesto, que se usan para almacenar conjuntos de elementos relacionados del mismo tipo o de tipos distintos:
# A) Llave
# B) Tupla
# C) Pickle
# D) Lista
# Concepto:Lista
# Muy bien :) correcto
#
# 4:Se utiliza para accesar una información en un diccionario:
# A) Sort
# B) Sorted
# C) Loop
# D) Llave
# Concepto:Llave
# Muy bien :) correcto
#
# ...
